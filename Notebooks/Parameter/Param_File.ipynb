# %%
storage_account = 'demoevent9641'            # name of storage account
storage_account_container = 'eventdemo'      # name of container in storage account
app_reg_client_id =  '61f1dae2-85f8-463f-9108-10eef6137d8e'    # Client id for app registrations
app_reg_secret_value =  'EB58Q~35UHAf7js2qLkIid6LNvB6U655dBlQocn3'   # secret value for app registrations
app_reg_tenantid =  '687f51c3-0c5d-4905-84f8-97c683a5b9d1'        # tenant id for app registrations
cosmos_db = 'rpm-hr-db'          # name of database created under cosmos db account
cosmos_db_container = 'rpm-hr-db-container'   # name of container created under cosmos db account
cosmos_db_endpoint = 'https://rpm-hr-db.documents.azure.com:443/'     # name of URI under keys for cosmos db account
cosmos_db_masterkey = 'dk805wja7Z9ec93l0XXRbbqYnFSgDfcBLOrgSsPyaxvtnp7GslhcUWVubso5Ta0PAQlPGf0mkdZq24dsMST9IA=='   # name of PRIMARY KEY under keys for cosmos db account
eventhub_connection_string = 'Endpoint=sb://demohealth.servicebus.windows.net/;SharedAccessKeyName=RootManageSharedAccessKey;SharedAccessKey=yVxBBZNugKUt8jnv6lOH7nF49C9W7mhQffEgl8IpoGw='   # Endpoint for Event hubs namespace
eventhub_instance = 'healthdemo'      # name of Event hub instance under Event hubs namespace
source_path = 'abfss://'+storage_account_container+'@'+storage_account+'.dfs.core.windows.net/'
app_reg_endpoint =  'https://login.microsoftonline.com/'+app_reg_tenantid+'/oauth2/token'
mount_point = '/mnt/'+storage_account_container
filepath='/dbfs'+mount_point
jsonfile='/dataset_json.json'
landing=mount_point +'/landing/'
historical=landing+'historical/'
eventhub_connection_string = eventhub_connection_string+';EntityPath='+eventhub_instance
duration = 'INTERVAL 1 Hour'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
